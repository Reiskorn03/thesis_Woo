# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import missingno as msno

# %%
SUBSET_FOLDER = "/Users/chanyoungwoo/Thesis/extracted_subsets"
SUBSETS = {
    "cand_kipa_subset":     "cand_kipa_subset_ver1.csv",
    "pra_hist_subset":      "pra_hist_subset_ver1.csv",
    "stathist_kipa_subset": "stathist_kipa_subset_ver1.csv",
    "tx_ki_subset":         "tx_ki_subset_ver1.csv",
    "txf_ki_subset":        "txf_ki_subset_ver1.csv",
}

for name, fname in SUBSETS.items():
    path = os.path.join(SUBSET_FOLDER, fname)
    df = pd.read_csv(path)
    
    print(f"\n--- Missingness in {name} ({df.shape[0]} rows × {df.shape[1]} cols) ---")
    
    # Missing rate in Percent
    miss_pct = df.isna().mean().mul(100).sort_values(ascending=False)
    summary = miss_pct.to_frame(name="Missing Values (%)")
    
    # Output: All Missing Values
    display(summary.head(110))
    
    # Save Missingness in seperate Column
    out_summary = os.path.join(SUBSET_FOLDER, f"{name}_missingness_summary.csv")
    summary.to_csv(out_summary, index=True)
    print(f"Saved in: {out_summary}")
    
    # Plot
    plt.figure(figsize=(10, 2))
    msno.bar(df, fontsize=8, figsize=(10,2))
    plt.title(f"Missingness in {name}")
    plt.show()
# Out:
# /var/folders/d8/czws1f3177g_k77xwyh5j8x40000gn/T/ipykernel_2400/2033053612.py:12: DtypeWarning: Columns (9,16,19,21,23,34,37,40,48,49,52,56,57,58) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)
# --- Missingness in cand_kipa_subset (1199290 rows × 79 cols) ---
#                           Missing Values (%)
# CAN_LIFE_SUPPORT                   99.999666
# CAN_PAIRED_LIVE_DONOR_ID           99.991161
# CAN_CMV_STAT                       99.943550
# CAN_PREV_KI_TX_FUNCTN              99.172427
# CAN_C_PEPTIDE                      98.671464
# ...                                      ...
# CAN_SOURCE                          0.000000
# ORG_AR                              0.000000
# CAN_PREV_TX                         0.000000
# CAN_PREV_KI                         0.000000
# PERS_ID                             0.000000
#
# [79 rows x 1 columns]
# Saved in: /Users/chanyoungwoo/Thesis/extracted_subsets/cand_kipa_subset_missingness_summary.csv
# --- Missingness in pra_hist_subset (4425413 rows × 7 cols) ---
#                      Missing Values (%)
# CANHX_ALLOC_PRA               60.337962
# CANHX_CUR_PRA                 57.916448
# CANHX_SRTR_PEAK_PRA           57.709619
# CANHX_CPRA                     3.400745
# PX_ID                          0.000000
# WL_ORG                         0.000000
# CANHX_BEGIN_DT                 0.000000
# Saved in: /Users/chanyoungwoo/Thesis/extracted_subsets/pra_hist_subset_missingness_summary.csv
# --- Missingness in stathist_kipa_subset (2169618 rows × 15 cols) ---
#                          Missing Values (%)
# CANHX_REASON_STAT_INACT           69.293811
# CAN_INIT_INACT_STAT_DT            27.297478
# CAN_LAST_INACT_STAT_DT            27.297478
# CAN_INIT_ACT_STAT_DT               5.025309
# CAN_LAST_ACT_STAT_DT               5.025309
# CAN_INIT_ACT_STAT_CD               5.025309
# CANHX_END_DT                       4.569745
# CANHX_END_DT_TM                    4.569745
# WL_ORG                             0.000000
# PX_ID                              0.000000
# CAN_INIT_STAT                      0.000000
# CAN_LISTING_DT                     0.000000
# CANHX_BEGIN_DT                     0.000000
# CANHX_STAT_CD                      0.000000
# CANHX_BEGIN_DT_TM                  0.000000
# Saved in: /Users/chanyoungwoo/Thesis/extracted_subsets/stathist_kipa_subset_missingness_summary.csv
# /var/folders/d8/czws1f3177g_k77xwyh5j8x40000gn/T/ipykernel_2400/2033053612.py:12: DtypeWarning: Columns (18,19,31,48,49,58,68,69,70,73,74,75,76,77,79,80,81,82) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)
# --- Missingness in tx_ki_subset (604267 rows × 107 cols) ---
#                                 Missing Values (%)
# REC_PREV_GRAFT3_DT                       99.964585
# REC_COD3                                 99.950188
# REC_COD2                                 99.832028
# REC_PREV_GRAFT2_DT                       99.749779
# REC_ACUTE_REJ_BIOPSY_CONFIRMED           99.227494
# ...                                            ...
# TRR_ID                                    0.000000
# DON_ETHNICITY_SRTR                        0.000000
# PX_ID                                     0.000000
# REC_TX_DT                                 0.000000
# DONOR_ID                                  0.000000
#
# [107 rows x 1 columns]
# Saved in: /Users/chanyoungwoo/Thesis/extracted_subsets/tx_ki_subset_missingness_summary.csv
# /var/folders/d8/czws1f3177g_k77xwyh5j8x40000gn/T/ipykernel_2400/2033053612.py:12: DtypeWarning: Columns (13,23,25,27,29,34,35,36,37,38,39,40,41,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)
# --- Missingness in txf_ki_subset (4794289 rows × 48 cols) ---
#                                 Missing Values (%)
# TFL_COD3                                 99.927455
# TFL_COD2                                 99.757149
# TFL_REJ_EVENT_NUM                        99.574348
# TFL_BK_THERAPY_TY                        99.571740
# TFL_ACUTE_REJ_BIOPSY_CONFIRMED           99.197295
# TFL_FAIL_BK                              99.071416
# TFL_CAD                                  98.796777
# TFL_AVN                                  98.543016
# TFL_MALIG_RECUR_TUMOR                    97.994280
# TFL_MALIG_DON_RELATED                    97.994280
# TFL_MALIG_TUMOR                          97.994134
# TFL_MALIG_LYMPH                          97.993175
# TFL_FAIL_REJ_CHRONIC                     97.748446
# TFL_FAIL_RECUR_DISEASE                   97.701974
# TFL_FAIL_UROL_COMPL                      97.699826
# TFL_FAIL_GRAFT_THROMB                    97.698908
# TFL_FAIL_INFECT                          97.698011
# TFL_FAIL_REJ_ACUTE                       97.694465
# TFL_COD                                  97.056331
# TFL_FAIL_CAUSE_TY                        96.142139
# TFL_FAIL_DT                              95.941067
# TFL_ANTIVRL_THERAPY_TY                   95.493889
# TFL_DISEASE_RECUR                        94.525632
# TFL_CMV_IGM                              84.782227
# TFL_CMV_IGG                              84.781956
# TFL_BK_THERAPY                           82.909228
# TFL_URINE_PROTEIN                        82.174959
# TFL_BMI                                  80.483112
# TFL_REJ_TREAT                            79.306483
# TFL_ANTIVRL_THERAPY                      73.733853
# TFL_IMMUNO_DISCONT                       72.428216
# TFL_FUNCTN_STAT                          33.611011
# TFL_MALIG                                12.789237
# TFL_CREAT                                12.340599
# TFL_GRAFT_STAT                            0.091463
# TFL_PX_STAT_DT                            0.007363
# TFL_PX_STAT                               0.004109
# PX_ID                                     0.000000
# REC_TX_TY                                 0.000000
# ORG_AR                                    0.000000
# TX_ID                                     0.000000
# TRR_FOL_ID                                0.000000
# TRR_ID                                    0.000000
# ORG_TY                                    0.000000
# REC_TX_DT                                 0.000000
# PERS_ID                                   0.000000
# TFL_FOL_CD                                0.000000
# REC_TX_ORG_TY                             0.000000
# Saved in: /Users/chanyoungwoo/Thesis/extracted_subsets/txf_ki_subset_missingness_summary.csv
